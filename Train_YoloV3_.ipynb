# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Create a dedicated Folder for this Notebook
# !ls 'drive/MyDrive/yolo_upenn_model' # Find the required directory and upload the custom_data.zip file and unzip it
# Out:
# classes.names  creating-files-data-and-name.py	     custom_data.zip  darknet
# classes.txt    creating-train-and-test-txt-files.py  custom_weight

# %%
# !unzip 'drive/MyDrive/yolo_upenn_model/custom_data.zip' -d 'drive/MyDrive/yolo_upenn_model/'
# Out:
# Archive:  drive/MyDrive/yolo_upenn_model/custom_data.zip
#   inflating: drive/MyDrive/yolo_upenn_model/custom_data/FudanPed00001.png
#   inflating: drive/MyDrive/yolo_upenn_model/custom_data/FudanPed00001.txt
#   inflating: drive/MyDrive/yolo_upenn_model/custom_data/FudanPed00002.png
#   inflating: drive/MyDrive/yolo_upenn_model/custom_data/FudanPed00002.txt
#   inflating: drive/MyDrive/yolo_upenn_model/custom_data/FudanPed00003.png
#   inflating: drive/MyDrive/yolo_upenn_model/custom_data/FudanPed00003.txt
#   inflating: drive/MyDrive/yolo_upenn_model/custom_data/FudanPed00004.png
#   inflating: drive/MyDrive/yolo_upenn_model/custom_data/FudanPed00004.txt
#   inflating: drive/MyDrive/yolo_upenn_model/custom_data/FudanPed00005.png
#   inflating: drive/MyDrive/yolo_upenn_model/custom_data/FudanPed00005.txt
#   inflating: drive/MyDrive/yolo_upenn_model/custom_data/FudanPed00006.png
#   inflating: drive/MyDrive/yolo_upenn_model/custom_data/FudanPed00006.txt
# ...

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' 'drive/MyDrive/yolo_upenn_model/darknet'
# Out:
# Cloning into 'drive/MyDrive/yolo_upenn_model/darknet'...
# remote: Enumerating objects: 15368, done.
# remote: Total 15368 (delta 0), reused 0 (delta 0), pack-reused 15368
# Receiving objects: 100% (15368/15368), 14.00 MiB | 4.97 MiB/s, done.
# Resolving deltas: 100% (10334/10334), done.
# Checking out files: 100% (2050/2050), done.

# %%
# %cd drive/MyDrive/yolo_upenn_model/darknet
# Out:
# /content/drive/MyDrive/yolo_upenn_model/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	json_mjpeg_streams.sh  scripts
# backup		darknet_images.py	LICENSE		       src
# build		darknet.py		Makefile	       vcpkg.json
# build.ps1	darknet_video.py	net_cam_v3.sh	       video_yolov3.sh
# cfg		data			net_cam_v4.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		obj
# CMakeLists.txt	image_yolov4.sh		README.md
# darknet		include			results

# %%
# change makefile to have GPU and OPENCV enabled
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# %cd /content/drive/MyDrive/yolo_upenn_model/custom_weight
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# /content/drive/MyDrive/yolo_upenn_model/custom_weight
# --2021-11-27 14:11:26--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  36.2MB/s    in 4.5s
#
# 2021-11-27 14:11:31 (34.6 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# %cd /content/drive/MyDrive/yolo_upenn_model
# Out:
# /content/drive/MyDrive/yolo_upenn_model

# %%
# !python custom_data/creating-files-data-and-name.py

# %%
# !python custom_data/creating-train-and-test-txt-files.py

# %%
# %cd /content/drive/MyDrive/yolo_custom_model_Training
# Out:
# /content/drive/MyDrive/yolo_custom_model_Training

# %%
# %cd /content/drive/MyDrive/yolo_upenn_model
# Out:
# /content/drive/MyDrive/yolo_upenn_model

# %%
# Start the training
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 58780, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.891160), count: 2, class_loss = 0.000068, iou_loss = 0.289180, total_loss = 0.289248
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000031, iou_loss = 0.000000, total_loss = 0.000031
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 58782, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.914480), count: 1, class_loss = 0.000068, iou_loss = 0.060202, total_loss = 0.060270
# ...
